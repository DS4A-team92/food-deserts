# %%
import os
import sys
import json
import pandas as pd

PROJ_ROOT = os.path.join(os.pardir)

# %%
clean_data_path = os.path.join(PROJ_ROOT, 
                         'data',
                         'processed',
                         'full_data.csv')
df=pd.read_csv(clean_data_path)

# %%
df.head(1)
# Out:
#    censustract  pop2010  ohu2010  groupquartersflag  numgqtrs  pctgqtrs  \
# 0  17031010100     4854     2302                  0     218.0      4.49
#
#    lilatracts_1and10  lilatracts_halfand10  lilatracts_1and20  \
# 0                  0                     1                  0
#
#    lilatracts_vehicle                        ...                          \
# 0                   1                        ...
#
#    taking medicine for high blood pressure control among adults aged >=18 years with high blood pressure  \
# 0                                               70.3
#
#    visits to dentist or dental clinic among adults aged >=18 years  \
# 0                                               60.4
#
#    visits to doctor for routine checkup within the past year among adults aged >=18 years  \
# 0                                               76.0
#
#    state          fips     mrfei  food_present      str_fips        geoid  \
# 0     IL  1.703101e+10  7.692308          True  1.703101e+10  17031010100
#
#                                               coords
# 0  [(-87.677199, 42.022942), (-87.670073, 42.0229...
#
# [1 rows x 96 columns]

# %%
json_data_path = os.path.join(PROJ_ROOT, 
                         'data',
                         'interim',
                         'column_names.json')
with open(json_data_path) as json_file:
    column_names = json.load(json_file)

# %%
df = df.rename(columns = column_names)

# %%
to_remove=set(df.columns)-set(column_names.values())

# %%
to_remove
# Out:
# {'fips',
#  'food_present',
#  'geoid',
#  'latracts10',
#  'latracts20',
#  'locationname',
#  'str_fips'}

# %%
df=df.drop(to_remove, axis=1)

# %%
df.head()
# Out:
#    census_tract  population  housing_units  group_qtr_flag  ct_grp_qtr  \
# 0   17031010100        4854           2302               0       218.0
# 1   17031010201        6450           2463               0       163.0
# 2   17031010202        2818           1115               0       315.0
# 3   17031010300        6236           2826               0       791.0
# 4   17031010400        5042           2098               0      1349.0
#
#    pct_grp_qtr  mf_ia_110  mf_ia_h110  mf_ia_120  mf_ia_vehicle  \
# 0         4.49          0           1          0              1
# 1         2.53          0           0          0              0
# 2        11.18          0           0          0              0
# 3        12.68          0           1          0              1
# 4        26.76          0           0          0              0
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#    prev_clinical_services_f  ho_physical_health  ub_sleep  ho_stroke  \
# 0                      25.4                11.9      39.8        3.2
# 1                      22.9                14.0      41.2        3.3
# 2                      24.1                13.6      39.1        3.8
# 3                      24.8                12.0      36.6        3.5
# 4                      27.4                 8.2      34.7        1.7
#
#    prev_med_bpressure  prev_dr_visits  prev_checkups  state      mrfei  \
# 0                70.3            60.4           76.0     IL   7.692308
# 1                67.5            52.7           73.4    NaN        NaN
# 2                72.4            57.3           75.0    NaN        NaN
# 3                73.3            62.8           75.4     IL  10.256410
# 4                62.2            68.7           71.8     IL   8.163265
#
#                                             geometry
# 0  [(-87.677199, 42.022942), (-87.670073, 42.0229...
# 1  [(-87.684653, 42.019484999999996), (-87.680448...
# 2  [(-87.67685499999999, 42.019411), (-87.673388,...
# 3  [(-87.67133, 42.019374), (-87.66949799999999, ...
# 4  [(-87.66345299999999, 42.01283), (-87.66132547...
#
# [5 rows x 89 columns]

# %%
clean_data_path = os.path.join(PROJ_ROOT, 
                         'data',
                         'processed',
                         'full_data_final.csv')
df.to_csv(clean_data_path,index=False)
