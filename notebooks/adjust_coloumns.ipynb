# %%
import os
import sys
import json
import pandas as pd

PROJ_ROOT = os.path.join(os.pardir)

# %%
clean_data_path = os.path.join(PROJ_ROOT, 
                         'data',
                         'processed',
                         'full_data.csv')
df=pd.read_csv(clean_data_path)

# %%
df.head(1)
# Out:
#    censustract   state_x       county  urban  pop2010  ohu2010  \
# 0  17031010100  Illinois  Cook County      1     4854     2302
#
#    groupquartersflag  numgqtrs  pctgqtrs  lilatracts_1and10  \
# 0                  0     218.0      4.49                  0
#
#                          ...                          \
# 0                        ...
#
#    stroke among adults aged >=18 years  \
# 0                                  3.2
#
#    taking medicine for high blood pressure control among adults aged >=18 years with high blood pressure  \
# 0                                               70.3
#
#    visits to dentist or dental clinic among adults aged >=18 years  \
# 0                                               60.4
#
#    visits to doctor for routine checkup within the past year among adults aged >=18 years  \
# 0                                               76.0
#
#    state_y          fips     mrfei      str_fips        geoid  \
# ...

# %%
json_data_path = os.path.join(PROJ_ROOT, 
                         'data',
                         'interim',
                         'column_names.json')
with open(json_data_path) as json_file:
    column_names = json.load(json_file)

# %%
column_names
# Out:
# {'censustract': 'census_tract',
#  'state_x': 'state',
#  'urban': 'urban_flag',
#  'pop2010': 'population',
#  'ohu2010': 'housing_units',
#  'groupquartersflag': 'group_qtr_flag',
#  'numgqtrs': 'ct_grp_qtr',
#  'pctgqtrs': 'pct_grp_qtr',
#  'lilatracts_1and10': 'mf_ia_110',
#  'lilatracts_halfand10': 'mf_ia_h110',
#  'lilatracts_1and20': 'mf_ia_120',
#  'lilatracts_vehicle': 'mf_ia_vehicle',
#  'hunvflag': 'f_vehicle_access_flag',
#  'lowincometracts': 'low_income',
#  'povertyrate': 'prop_in_pov',
#  'medianfamilyincome': 'median_income',
#  'la1and10': 'mf_a_110',
#  'lahalfand10': 'mf_a_h110',
#  'la1and20': 'mf_a_120',
#  'latracts_half': 'mf_a_h1',
#  'latracts1': 'mf_a_1',
#  'latractsvehicle_20': 'f_v_access_add_flag',
#  'lapop1_10': 'ct_pop_la_110',
#  'lapop05_10': 'ct_pop_la_h110',
#  'lapop1_20': 'ct_pop_la_120',
#  'lalowi1_10': 'ct_ai_110',
#  'lalowi05_10': 'ct_ai_h110',
#  'lalowi1_20': 'ct_ai_120',
#  'lapophalf': 'ct_a_h1',
#  'lapophalfshare': 'prop_a_h1',
# ...

# %%
df = df.rename(columns = column_names)

# %%
to_remove=set(df.columns)-set(column_names.values())

# %%
df=df.drop(to_remove, axis=1)

# %%
df.head()
# Out:
#    census_tract     state  urban_flag  population  housing_units  \
# 0   17031010100  Illinois           1        4854           2302
# 1   17031010201  Illinois           1        6450           2463
# 2   17031010202  Illinois           1        2818           1115
# 3   17031010300  Illinois           1        6236           2826
# 4   17031010400  Illinois           1        5042           2098
#
#    group_qtr_flag  ct_grp_qtr  pct_grp_qtr  mf_ia_110  mf_ia_h110  \
# 0               0       218.0         4.49          0           1
# 1               0       163.0         2.53          0           0
# 2               0       315.0        11.18          0           0
# 3               0       791.0        12.68          0           1
# 4               0      1349.0        26.76          0           0
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# ...

# %%
clean_data_path = os.path.join(PROJ_ROOT, 
                         'data',
                         'processed',
                         'full_data_final.csv')
df.to_csv(clean_data_path,index=False)
