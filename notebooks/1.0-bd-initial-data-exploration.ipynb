# %%
# !pip install -r requirements.txt

# %%
import os
import sys

import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
PROJ_ROOT = os.path.join(os.pardir)

# %%
data_path = os.path.join(PROJ_ROOT, 
                         'data',
                          'raw',
                          'food_access_file',
                         'Food Access Research Atlas.csv')

df = pd.read_csv(data_path)

# %%
df=df[df.State=='Illinois']

# %%
df.head()
# Out:
#        CensusTract     State        County  Urban  Pop2010  OHU2010  \
# 20796  17001000100  Illinois  Adams County      1     4627     2115
# 20797  17001000201  Illinois  Adams County      1     1986      872
# 20798  17001000202  Illinois  Adams County      1     2999     1046
# 20799  17001000400  Illinois  Adams County      1     4322     1534
# 20800  17001000500  Illinois  Adams County      1     2337      889
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 20796                  0      23.0      0.50                  1  ...
# 20797                  0      20.0      1.01                  0  ...
# 20798                  0     549.0     18.31                  0  ...
# 20799                  0     589.0     13.63                  0  ...
# 20800                  0     273.0     11.68                  0  ...
#
#        TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  \
# 20796        1074.0      4412.0        62.0        45.0         1.0
# 20797         326.0      1882.0        53.0         9.0         1.0
# 20798         289.0      2688.0       215.0        14.0         1.0
# 20799         890.0      3527.0       582.0        13.0         0.0
# 20800         429.0      1872.0       380.0         6.0         1.0
#
#        TractAIAN  TractOMultir  TractHispanic  TractHUNV  TractSNAP
# 20796        7.0         100.0           72.0      117.0      286.0
# 20797        2.0          39.0           18.0       54.0      111.0
# 20798        9.0          72.0           62.0       48.0       79.0
# 20799        9.0         191.0           78.0      322.0      452.0
# 20800        5.0          73.0           18.0      153.0      203.0
#
# [5 rows x 147 columns]
