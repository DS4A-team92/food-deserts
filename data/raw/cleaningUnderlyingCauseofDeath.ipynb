# %%
import pandas as pd
import numpy as np

# %%
f = open("Underlying Cause of Death, 1999-2019.txt", "r")
print(f.readline())
# Out:
# "Notes"	"County"	"County Code"	"Year"	"Year Code"	"Cause of death"	"Cause of death Code"	Deaths	Population	Crude Rate

# %%
df = pd.read_csv('Underlying Cause of Death, 1999-2019.txt', delimiter = "\t")
df
# Out:
#                                                   Notes            County  \
# 0                                                   NaN  Adams County, IL
# 1                                                   NaN  Adams County, IL
# 2                                                   NaN  Adams County, IL
# 3                                                   NaN  Adams County, IL
# 4                                                   NaN  Adams County, IL
# ...                                                 ...               ...
# 6556  2019 data. Underlying and multiple cause of de...               NaN
# 6557  unspecified firearm discharge, ICD-10 code X95...               NaN
# 6558                                              2020.               NaN
# 6559  6. Changes to cause of death classification af...               NaN
# 6560  http://wonder.cdc.gov/wonder/help/ucd.html#ICD...               NaN
#
#       County Code    Year  Year Code  \
# 0         17001.0  2016.0     2016.0
# ...

# %%
df.columns
# Out:
# Index(['Notes', 'County', 'County Code', 'Year', 'Year Code', 'Cause of death',
#        'Cause of death Code', 'Deaths', 'Population', 'Crude Rate'],
#       dtype='object')

# %%
df2 = df.dropna(subset=['County', 'County Code', 'Cause of death'])
df2
# Out:
#      Notes               County  County Code    Year  Year Code  \
# 0      NaN     Adams County, IL      17001.0  2016.0     2016.0
# 1      NaN     Adams County, IL      17001.0  2016.0     2016.0
# 2      NaN     Adams County, IL      17001.0  2016.0     2016.0
# 3      NaN     Adams County, IL      17001.0  2016.0     2016.0
# 4      NaN     Adams County, IL      17001.0  2016.0     2016.0
# ...    ...                  ...          ...     ...        ...
# 6496   NaN  Woodford County, IL      17203.0  2019.0     2019.0
# 6497   NaN  Woodford County, IL      17203.0  2019.0     2019.0
# 6498   NaN  Woodford County, IL      17203.0  2019.0     2019.0
# 6499   NaN  Woodford County, IL      17203.0  2019.0     2019.0
# 6500   NaN  Woodford County, IL      17203.0  2019.0     2019.0
#
#                                          Cause of death Cause of death Code  \
# 0                              Septicaemia, unspecified               A41.9
# ...

# %%
df2[df2.County.str.contains('Cook',case=False)]
# Out:
#      Notes           County  County Code    Year  Year Code  \
# 382    NaN  Cook County, IL      17031.0  2016.0     2016.0
# 383    NaN  Cook County, IL      17031.0  2016.0     2016.0
# 384    NaN  Cook County, IL      17031.0  2016.0     2016.0
# 385    NaN  Cook County, IL      17031.0  2016.0     2016.0
# 386    NaN  Cook County, IL      17031.0  2016.0     2016.0
# ...    ...              ...          ...     ...        ...
# 1606   NaN  Cook County, IL      17031.0  2019.0     2019.0
# 1607   NaN  Cook County, IL      17031.0  2019.0     2019.0
# 1608   NaN  Cook County, IL      17031.0  2019.0     2019.0
# 1609   NaN  Cook County, IL      17031.0  2019.0     2019.0
# 1610   NaN  Cook County, IL      17031.0  2019.0     2019.0
#
#                                          Cause of death Cause of death Code  \
# 382          Enterocolitis due to Clostridium difficile               A04.7
# 383   Gastroenteritis and colitis of unspecified origin               A09.9
# ...

# %%
df2 = df2.drop(columns=["Notes"])
df2
# Out:
#                    County  County Code    Year  Year Code  \
# 0        Adams County, IL      17001.0  2016.0     2016.0
# 1        Adams County, IL      17001.0  2016.0     2016.0
# 2        Adams County, IL      17001.0  2016.0     2016.0
# 3        Adams County, IL      17001.0  2016.0     2016.0
# 4        Adams County, IL      17001.0  2016.0     2016.0
# ...                   ...          ...     ...        ...
# 6496  Woodford County, IL      17203.0  2019.0     2019.0
# 6497  Woodford County, IL      17203.0  2019.0     2019.0
# 6498  Woodford County, IL      17203.0  2019.0     2019.0
# 6499  Woodford County, IL      17203.0  2019.0     2019.0
# 6500  Woodford County, IL      17203.0  2019.0     2019.0
#
#                                          Cause of death Cause of death Code  \
# 0                              Septicaemia, unspecified               A41.9
# 1              Colon, unspecified - Malignant neoplasms               C18.9
# ...

# %%
df.dtypes
# Out:
# Notes                   object
# County                  object
# County Code            float64
# Year                   float64
# Year Code              float64
# Cause of death          object
# Cause of death Code     object
# Deaths                 float64
# Population             float64
# Crude Rate              object
# dtype: object

# %%
df2['Crude Rate'] = pd.to_numeric(df['Crude Rate'], errors='coerce') #coverts strings to NaN values
df2
# Out:
#                    County  County Code    Year  Year Code  \
# 0        Adams County, IL      17001.0  2016.0     2016.0
# 1        Adams County, IL      17001.0  2016.0     2016.0
# 2        Adams County, IL      17001.0  2016.0     2016.0
# 3        Adams County, IL      17001.0  2016.0     2016.0
# 4        Adams County, IL      17001.0  2016.0     2016.0
# ...                   ...          ...     ...        ...
# 6496  Woodford County, IL      17203.0  2019.0     2019.0
# 6497  Woodford County, IL      17203.0  2019.0     2019.0
# 6498  Woodford County, IL      17203.0  2019.0     2019.0
# 6499  Woodford County, IL      17203.0  2019.0     2019.0
# 6500  Woodford County, IL      17203.0  2019.0     2019.0
#
#                                          Cause of death Cause of death Code  \
# 0                              Septicaemia, unspecified               A41.9
# 1              Colon, unspecified - Malignant neoplasms               C18.9
# ...

# %%
df2['Crude Rate'] = df2['Crude Rate'].fillna(0) #coverts NaN to zeros, floating
df2
# Out:
#                    County  County Code    Year  Year Code  \
# 0        Adams County, IL      17001.0  2016.0     2016.0
# 1        Adams County, IL      17001.0  2016.0     2016.0
# 2        Adams County, IL      17001.0  2016.0     2016.0
# 3        Adams County, IL      17001.0  2016.0     2016.0
# 4        Adams County, IL      17001.0  2016.0     2016.0
# ...                   ...          ...     ...        ...
# 6496  Woodford County, IL      17203.0  2019.0     2019.0
# 6497  Woodford County, IL      17203.0  2019.0     2019.0
# 6498  Woodford County, IL      17203.0  2019.0     2019.0
# 6499  Woodford County, IL      17203.0  2019.0     2019.0
# 6500  Woodford County, IL      17203.0  2019.0     2019.0
#
#                                          Cause of death Cause of death Code  \
# 0                              Septicaemia, unspecified               A41.9
# 1              Colon, unspecified - Malignant neoplasms               C18.9
# ...

# %%
df2.dtypes
# Out:
# County                  object
# County Code            float64
# Year                   float64
# Year Code              float64
# Cause of death          object
# Cause of death Code     object
# Deaths                 float64
# Population             float64
# Crude Rate               int64
# dtype: object

# %%
df2["Crude Rate"] = df2["Crude Rate"].astype("int64")
df2
# Out:
#                    County  County Code    Year  Year Code  \
# 0        Adams County, IL      17001.0  2016.0     2016.0
# 1        Adams County, IL      17001.0  2016.0     2016.0
# 2        Adams County, IL      17001.0  2016.0     2016.0
# 3        Adams County, IL      17001.0  2016.0     2016.0
# 4        Adams County, IL      17001.0  2016.0     2016.0
# ...                   ...          ...     ...        ...
# 6496  Woodford County, IL      17203.0  2019.0     2019.0
# 6497  Woodford County, IL      17203.0  2019.0     2019.0
# 6498  Woodford County, IL      17203.0  2019.0     2019.0
# 6499  Woodford County, IL      17203.0  2019.0     2019.0
# 6500  Woodford County, IL      17203.0  2019.0     2019.0
#
#                                          Cause of death Cause of death Code  \
# 0                              Septicaemia, unspecified               A41.9
# 1              Colon, unspecified - Malignant neoplasms               C18.9
# ...

# %%
df2.dtypes
# Out:
# County                  object
# County Code            float64
# Year                   float64
# Year Code              float64
# Cause of death          object
# Cause of death Code     object
# Deaths                 float64
# Population             float64
# Crude Rate               int64
# dtype: object

# %%
df2[["Year", "Year Code"]] = df2[["Year", "Year Code"]].apply(pd.to_numeric, errors='coerce', axis=1)
# df2.astype({'Year':'int64'}).dtypes
# cols = ['col1', 'col2', 'col3']
# data[cols] = data[cols].apply(pd.to_numeric, errors='coerce', axis=1)
df2
# Out:
#                    County  County Code    Year  Year Code  \
# 0        Adams County, IL      17001.0  2016.0     2016.0
# 1        Adams County, IL      17001.0  2016.0     2016.0
# 2        Adams County, IL      17001.0  2016.0     2016.0
# 3        Adams County, IL      17001.0  2016.0     2016.0
# 4        Adams County, IL      17001.0  2016.0     2016.0
# ...                   ...          ...     ...        ...
# 6496  Woodford County, IL      17203.0  2019.0     2019.0
# 6497  Woodford County, IL      17203.0  2019.0     2019.0
# 6498  Woodford County, IL      17203.0  2019.0     2019.0
# 6499  Woodford County, IL      17203.0  2019.0     2019.0
# 6500  Woodford County, IL      17203.0  2019.0     2019.0
#
#                                          Cause of death Cause of death Code  \
# 0                              Septicaemia, unspecified               A41.9
# 1              Colon, unspecified - Malignant neoplasms               C18.9
# ...

# %%
df2.dtypes
# Out:
# County                  object
# County Code            float64
# Year                   float64
# Year Code              float64
# Cause of death          object
# Cause of death Code     object
# Deaths                 float64
# Population             float64
# Crude Rate               int64
# dtype: object

# %%
df2[["County Code","Year","Year Code","Deaths","Population"]] = df2[["County Code","Year","Year Code","Deaths","Population"]].astype("int64")
df2
# Out:
#                    County  County Code  Year  Year Code  \
# 0        Adams County, IL        17001  2016       2016
# 1        Adams County, IL        17001  2016       2016
# 2        Adams County, IL        17001  2016       2016
# 3        Adams County, IL        17001  2016       2016
# 4        Adams County, IL        17001  2016       2016
# ...                   ...          ...   ...        ...
# 6496  Woodford County, IL        17203  2019       2019
# 6497  Woodford County, IL        17203  2019       2019
# 6498  Woodford County, IL        17203  2019       2019
# 6499  Woodford County, IL        17203  2019       2019
# 6500  Woodford County, IL        17203  2019       2019
#
#                                          Cause of death Cause of death Code  \
# 0                              Septicaemia, unspecified               A41.9
# 1              Colon, unspecified - Malignant neoplasms               C18.9
# ...

# %%
df2.dtypes
# Out:
# County                 object
# County Code             int64
# Year                    int64
# Year Code               int64
# Cause of death         string
# Cause of death Code    object
# Deaths                  int64
# Population              int64
# Crude Rate              int64
# dtype: object

# %%
df2[["County","Cause of death"]] = df2[["County","Cause of death"]].astype("string")
df2
# Out:
#                    County  County Code  Year  Year Code  \
# 0        Adams County, IL        17001  2016       2016
# 1        Adams County, IL        17001  2016       2016
# 2        Adams County, IL        17001  2016       2016
# 3        Adams County, IL        17001  2016       2016
# 4        Adams County, IL        17001  2016       2016
# ...                   ...          ...   ...        ...
# 6496  Woodford County, IL        17203  2019       2019
# 6497  Woodford County, IL        17203  2019       2019
# 6498  Woodford County, IL        17203  2019       2019
# 6499  Woodford County, IL        17203  2019       2019
# 6500  Woodford County, IL        17203  2019       2019
#
#                                          Cause of death Cause of death Code  \
# 0                              Septicaemia, unspecified               A41.9
# 1              Colon, unspecified - Malignant neoplasms               C18.9
# ...

# %%
df2.dtypes
# Out:
# County                 string
# County Code             int64
# Year                    int64
# Year Code               int64
# Cause of death         string
# Cause of death Code    object
# Deaths                  int64
# Population              int64
# Crude Rate              int64
# dtype: object

# %%
df2 = df2.drop(columns=["Cause of death Code"])
df2
# Out:
#                    County  County Code  Year  Year Code  \
# 0        Adams County, IL        17001  2016       2016
# 1        Adams County, IL        17001  2016       2016
# 2        Adams County, IL        17001  2016       2016
# 3        Adams County, IL        17001  2016       2016
# 4        Adams County, IL        17001  2016       2016
# ...                   ...          ...   ...        ...
# 6496  Woodford County, IL        17203  2019       2019
# 6497  Woodford County, IL        17203  2019       2019
# 6498  Woodford County, IL        17203  2019       2019
# 6499  Woodford County, IL        17203  2019       2019
# 6500  Woodford County, IL        17203  2019       2019
#
#                                          Cause of death  Deaths  Population  \
# 0                              Septicaemia, unspecified      29       66578
# 1              Colon, unspecified - Malignant neoplasms      12       66578
# ...

# %%
df2.dtypes
# Out:
# County            string
# County Code        int64
# Year               int64
# Year Code          int64
# Cause of death    string
# Deaths             int64
# Population         int64
# Crude Rate         int64
# dtype: object

# %%
#clean data
df2 = df2[df2.County.str.contains('Cook',case=False)]
df2
# Out:
#                County  County Code  Year  Year Code  \
# 382   Cook County, IL        17031  2016       2016
# 383   Cook County, IL        17031  2016       2016
# 384   Cook County, IL        17031  2016       2016
# 385   Cook County, IL        17031  2016       2016
# 386   Cook County, IL        17031  2016       2016
# ...               ...          ...   ...        ...
# 1606  Cook County, IL        17031  2019       2019
# 1607  Cook County, IL        17031  2019       2019
# 1608  Cook County, IL        17031  2019       2019
# 1609  Cook County, IL        17031  2019       2019
# 1610  Cook County, IL        17031  2019       2019
#
#                                          Cause of death  Deaths  Population  \
# 382          Enterocolitis due to Clostridium difficile      62     5203499
# 383   Gastroenteritis and colitis of unspecified origin      17     5203499
# 384            Septicaemia due to Staphylococcus aureus      16     5203499
# ...

# %%
df2.dtypes
# Out:
# County            string
# County Code        int64
# Year               int64
# Year Code          int64
# Cause of death    string
# Deaths             int64
# Population         int64
# Crude Rate         int64
# dtype: object

# %%
df2.to_csv('clean_underlyingcauseofdeath.csv')
